# %% [markdown]
# ## Introduction
# Hello, Nama saya Ridzki Darykholaf Hendriansyah, saya lahir di Jakarta, 11 Maret 1998, Saya adalah siswa dari Hacktive 8. Disini saya akan membuat suatu hipotesa dari data set yang sudah disediakan, berikut pensimulasiannya

# %% [markdown]
# ### Importing Library yang akan digunakan
# Pada simulasi kali ini menggunakan library:
# - Pandas
# - Matplotlib
# - scipy
# - seaborn
# - numpy
# - statistic

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import numpy as np
import statistics

# %% [markdown]
# Setelah itu melakukan pembacaan file csv menggunakan pandas

# %%
df=pd.read_csv('supermarket_sales.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# Dari data set diatas bisa dilihat bahwa data set memiliki sebanyak 1000 rows dengan 17 columns yang terdapat dalam DataSet diatas

# %% [markdown]
# ## Eksplorasi Missing Value

# %% [markdown]
# Melakukan pencarian Missing Value

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# Tidak terdapat missing value pada DataSet diatas, selanjutnya melakukan pengecekan duplikasi data, apakah ada atau tidak

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Dari hasil diatas dinyatakan bahwa data tidak memiliki duplikasi data

# %% [markdown]
# ## Hipotesis Testing Dependend 2 Tailed

# %% [markdown]
# Disini saya ingin melihat negara apa saja dan berapa data yang masuk per negara pada DataSet diatas, berikut simulasinya:

# %%
for i in ['City']:               #Melakukan looping dengan kolom City untuk mengetahui kota apa saja yang terdapat dalam DataSet
    print(i, ':')
    print(df[i].value_counts())
    print('-'*50)
# Out:
# City :
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64
# --------------------------------------------------

# %% [markdown]
# Terdapat 3 kota yang terdapat dalam DataSet `Supermarket` diantaranya adalah:
# - Yangon dengan 340 Entry Data
# - Mandalay dengan 332 Entry Data
# - Napytaw dengan 328 Entry Data

# %%
YG= df[df.City=='Yangon'] 
MD= df[df.City=='Mandalay'] 
NT= df[df.City=='Naypyitaw']

# %%
YG.describe().T
# Out:
#                          count        mean         std        min         25%  \
# Unit price               340.0   54.780853   26.132127  10.080000   32.250000
# Quantity                 340.0    5.467647    2.859876   1.000000    3.000000
# Tax 5%                   340.0   14.874001   11.030477   0.604500    6.547125
# Total                    340.0  312.354031  231.640025  12.694500  137.489625
# cogs                     340.0  297.480029  220.609547  12.090000  130.942500
# gross margin percentage  340.0    4.761905    0.000000   4.761905    4.761905
# gross income             340.0   14.874001   11.030477   0.604500    6.547125
# Rating                   340.0    7.027059    1.731345   4.000000    5.600000
#
#                                 50%         75%          max
# Unit price                53.235000   75.095000    99.830000
# Quantity                   5.000000    8.000000    10.000000
# Tax 5%                    11.468000   21.873375    49.490000
# ...

# %% [markdown]
# Didapati pada kota Yangoon memiliki rata-rata Gross Income sebesar `14.87`

# %%
MD.describe().T
# Out:
#                          count        mean         std        min         25%  \
# Unit price               332.0   55.659277   26.224559  10.590000   33.300000
# Quantity                 332.0    5.481928    2.896446   1.000000    3.000000
# Tax 5%                   332.0   15.232024   11.545122   0.887500    5.711250
# Total                    332.0  319.872506  242.447565  18.637500  119.936250
# cogs                     332.0  304.640482  230.902443  17.750000  114.225000
# gross margin percentage  332.0    4.761905    0.000000   4.761905    4.761905
# gross income             332.0   15.232024   11.545122   0.887500    5.711250
# Rating                   332.0    6.818072    1.713719   4.000000    5.300000
#
#                                 50%         75%          max
# Unit price                54.850000   77.002500    99.960000
# Quantity                   5.000000    8.000000    10.000000
# Tax 5%                    12.042000   22.170750    48.690000
# ...

# %% [markdown]
# Didapati pada kota Mandalay memiliki rata-rata Gross Income sebesar `15.23`

# %%
NT.describe().T
# Out:
#                          count        mean         std        min         25%  \
# Unit price               328.0   56.609024   27.179799  10.160000   33.767500
# Quantity                 328.0    5.582317    3.021724   1.000000    3.000000
# Tax 5%                   328.0   16.052367   12.531470   0.508500    5.784500
# Total                    328.0  337.099715  263.160870  10.678500  121.474500
# cogs                     328.0  321.047348  250.629400  10.170000  115.690000
# gross margin percentage  328.0    4.761905    0.000000   4.761905    4.761905
# gross income             328.0   16.052367   12.531470   0.508500    5.784500
# Rating                   328.0    7.072866    1.704526   4.000000    5.600000
#
#                                 50%         75%          max
# Unit price                56.810000   81.552500    99.960000
# Quantity                   6.000000    8.000000    10.000000
# Tax 5%                    12.924750   23.607375    49.650000
# ...

# %% [markdown]
# Dan untuk kota Naypyitaw didapat rata-rata Gross Income sebesar `16.05`

# %% [markdown]
# Dari data diatas bisa disimpulkan bahwa rata rata gross income dari ketiga kota tersebut adalah:
# - Yangoon memiliki rata-rata Gross Income sebesar `14.87`
# - Mandalay memiliki rata-rata Gross Income sebesar `15.23`
# - Mandalay memiliki rata-rata Gross Income sebesar `16.05`
#
# Jika dilihat dari data diatas, nilai rata rata gross income terkecil terdapat pada kota Yangoon dengan Gross Income sebesar `14.87`, Lalu bagaimana cara menaikan nilai gross income pada kota Yangoon?
#
# Kali ini saya akan menganalisis berdasarkan entry data berdasarkan gender pada supermarket cabang kota Yangoon, Gender mana yang paling berpengaruh sehingga Supermarket pada kota Yangoon bisa melakukan perbuhan strategi bisnis, berikut simulasinya:

# %%
#Melakukan value count terhadap Gender di kota Yangoon
for i in ['Gender']:               
    print(i, ':')
    print(YG[i].value_counts())
    print('-'*50)
# Out:
# Gender :
# Male      179
# Female    161
# Name: Gender, dtype: int64
# --------------------------------------------------

# %% [markdown]
# Dari data diatas didapati bahwa banyaknya Laki-laki yang berbelanja dan wanita adalah:
# - Male sebanyak 179 Entry Data
# - Female sebanyak 161 Entry Data
# Akan tetapi yang manakah yang memiliki Rata rata gross income terbesar?
# Berikut simulasinya:

# %%
#Melakukan Data Query dengan menquery data kota Yangoon dan mengkelompokannya menjadi Female dan Male
ygf=YG[YG.Gender=='Female'] 
ygm=YG[YG.Gender=='Male']

# %%
ygf.describe().T
# Out:
#                          count        mean         std        min         25%  \
# Unit price               161.0   56.086149   27.107476  10.690000   32.250000
# Quantity                 161.0    5.645963    2.793765   1.000000    4.000000
# Tax 5%                   161.0   15.755447   11.098508   0.604500    7.693000
# Total                    161.0  330.864391  233.068675  12.694500  161.553000
# cogs                     161.0  315.108944  221.970167  12.090000  153.860000
# gross margin percentage  161.0    4.761905    0.000000   4.761905    4.761905
# gross income             161.0   15.755447   11.098508   0.604500    7.693000
# Rating                   161.0    6.839130    1.735986   4.100000    5.200000
#
#                                 50%         75%         max
# Unit price                54.270000   77.930000   99.600000
# Quantity                   5.000000    8.000000   10.000000
# Tax 5%                    12.245000   22.370000   45.325000
# ...

# %% [markdown]
# Didapati pada kota Yangoon dengan Gender Female  memiliki rata-rata Gross Income sebesar `15.755447`

# %%
ygm.describe().T
# Out:
#                          count        mean           std        min  \
# Unit price               179.0   53.606816  2.524126e+01  10.080000
# Quantity                 179.0    5.307263  2.916536e+00   1.000000
# Tax 5%                   179.0   14.081193  1.093924e+01   0.914000
# Total                    179.0  295.705047  2.297240e+02  19.194000
# cogs                     179.0  281.623855  2.187848e+02  18.280000
# gross margin percentage  179.0    4.761905  8.906698e-16   4.761905
# gross income             179.0   14.081193  1.093924e+01   0.914000
# Rating                   179.0    7.196089  1.714425e+00   4.000000
#
#                                25%         50%         75%          max
# Unit price               32.355000   52.750000   73.975000    99.830000
# Quantity                  3.000000    5.000000    8.000000    10.000000
# Tax 5%                    4.753750   11.100000   21.580000    49.490000
# ...

# %% [markdown]
# Didapati pada kota Yangoon dengan Gender Male  memiliki rata-rata Gross Income sebesar `14.081193`

# %% [markdown]
# Dari data diatas bisa disimpulkan bahwa rata rata gross income dikota Yangoon dari kedua gender tersebut adalah:
# - Female memiliki rata-rata Gross Income sebesar `15.75`
# - Male memiliki rata-rata Gross Income sebesar `14.081`
# Secara kasat mata rata-rata gross income pada Female dan Male bereda dengan Rata-rata Female > Rata-rata Male
# tapi apakah berbeda signifikan? apakah tidak? Mari buktikan dengan Hipotesa!

# %% [markdown]
# ## Hipotesa
# Setelah ditemukan data diatas saya ingin membuat hipotesis berupa:
# - H0: μ YGF == μ YGM Maksudnya adalah jika nilai Rata rata sample Female == Rata-rata sample Male
#
# - H1: μ YGF != μ YGM Maksudnya adalah jika nilai Rata rata sample Female != Rata-rata sample Male

# %%
t_stat, p_val = stats.ttest_ind(ygf['gross income'], ygm ['gross income'])
# T-test itu secara default menggunakan 2 tail, jadi tidak perlu dibagi 2/0,5
print('P-value:',p_val)       #Menampilkan P-Value
print('t-statistics:',t_stat)   #Menampilkan T-Statistic
# Out:
# P-value: 0.16261180081238572
# t-statistics: 1.3993944019116016

# %% [markdown]
# Dari sini bisa disimpulkan bahwa H0 diterima , akan tetapi saya akan mencoba membuktikannya lagi berdasarkan grafik, berikut simulasinya:

# %%
# simulation
ygf_pop = np.random.normal(ygf['gross income'].mean(),ygf['gross income'].std(),10000)
ygm_pop = np.random.normal(ygm['gross income'].mean(),ygm['gross income'].std(),10000)

# confidence interval based on gen 4
# menggunakan critical value sebesar 0.05 ,ketika 2 tailed confidence interval menjadi 0.95
ci = stats.norm.interval(0.95, ygf['gross income'].mean(), ygf['gross income'].std())

plt.figure(figsize=(16,5))
sns.distplot(ygf_pop, label='Yangoon Female Gross Income ',color='blue')
sns.distplot(ygm_pop, label='Yangoon Male Gross Income ',color='red')

# mean
plt.axvline(ygf['gross income'].mean(), color='blue', linewidth=2, label='Yangoon Female Gross Income mean')
plt.axvline(ygm['gross income'].mean(), color='red',  linewidth=2, label='Yangoon Male Gross Income mean')

plt.axvline(ci[1], color='green', linestyle='dashed', linewidth=2, label='confidence threshold of 95%')
plt.axvline(ci[0], color='green', linestyle='dashed', linewidth=2, label='confidence threshold of 95%')

# alternative hypotesis
plt.axvline(ygm_pop.mean()+t_stat*ygm_pop.std(), color='black', linestyle='dashed', linewidth=2, label = 'Alternative Hypothesis')
plt.axvline(ygm_pop.mean()-t_stat*ygm_pop.std(), color='black', linestyle='dashed', linewidth=2)

plt.legend()
print(ci[0])
# Out:
# C:\Users\ridzk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ridzk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# -5.997229454239564

# %% [markdown]
# ### Kesimpulan
#
# Berdasarkan hasil analisis di atas bisa disimpulkan bahwa:
# - Nilai P-value > Critical Value yaitu 0.16261180081238572 >  5%
# - Berdasarkan dari data diatas bisa dilihat bahwa nilai dari Alternatif Hypothesis (X) didalam batas Critical Value (cv) sehingga dapat disimpulkan bahwa nilai Rata rata sample Female memiliki buktinya yang cukup sama dengan Rata-rata sample Male
# - Jadi hipotesis yang dapat disimpulkan yaitu :
# - H0: μ YGF == μ YGM Maksudnya adalah jika nilai Rata rata sample Female == Rata-rata sample Male
#
# Itu menandakan bahwa Rata-rata gross income antara Gender Laki-laki dengan Gender Female memiliki kesamaan, tetapi kalau dilihat dari nilai Mean yang dimiliki keduanya, tetap Gender Female yang lebih besar dibanding Gender Male (F> M). Maka dari itu saya menyarankan untuk memfokuskuskan sedikit penjualan ke arah Gender Perempuan akan tetapi tidak mengabaikan pula untuk Gender Laki-laki
